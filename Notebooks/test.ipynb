# %% [markdown]
# # TEXT2SQL

# %%
import os
import json
import transformers

pretrained_weights = {
    ("bert", "base"): "bert-base-uncased",
    ("bert", "large"): "bert-large-uncased-whole-word-masking",
    ("roberta", "base"): "roberta-base",
    ("roberta", "large"): "roberta-large",
    ("albert", "xlarge"): "albert-xlarge-v2"
}

def read_jsonl(jsonl):
    for line in open(jsonl, encoding="utf8"):
        sample = json.loads(line.rstrip())
        yield sample

def read_conf(conf_path):
    config = {}
    for line in open(conf_path, encoding="utf8"):
        if line.strip() == "" or line[0] == "#":
             continue
        fields = line.strip().split("\t")
        config[fields[0]] = fields[1]
    config["train_data_path"] =  os.path.abspath(config["train_data_path"])
    config["dev_data_path"] =  os.path.abspath(config["dev_data_path"])

    return config

def create_base_model(config):
    weights_name = pretrained_weights[(config["base_class"], config["base_name"])]
    if config["base_class"] == "bert":
        return transformers.BertModel.from_pretrained(weights_name)
    elif config["base_class"] == "roberta":
        return transformers.RobertaModel.from_pretrained(weights_name)
    elif config["base_class"] == "albert":
        return transformers.AlbertModel.from_pretrained(weights_name)
    else:
        raise Exception("base_class {0} not supported".format(config["base_class"]))

def create_tokenizer(config):
    weights_name = pretrained_weights[(config["base_class"], config["base_name"])]
    if config["base_class"] == "bert":
        return transformers.BertTokenizer.from_pretrained(weights_name)
    elif config["base_class"] == "roberta":
        return transformers.RobertaTokenizer.from_pretrained(weights_name)
    elif config["base_class"] == "albert":
        return transformers.AlbertTokenizer.from_pretrained(weights_name)
    else:
        raise Exception("base_class {0} not supported".format(config["base_class"]))

# %%
import json
import os
import string
import unicodedata

def is_whitespace(c):
    if c == " " or c == "\t" or c == "\n" or c == "\r":
        return True
    cat = unicodedata.category(c)
    if cat == "Zs":
        return True
    return False

def is_punctuation(c):
    """Checks whether `chars` is a punctuation character."""
    cp = ord(c)
    # We treat all non-letter/number ASCII as punctuation.
    # Characters such as "^", "$", and "`" are not in the Unicode
    # Punctuation class but we treat them as punctuation anyways, for
    # consistency.
    if ((cp >= 33 and cp <= 47) or (cp >= 58 and cp <= 64) or
        (cp >= 91 and cp <= 96) or (cp >= 123 and cp <= 126)):
        return True
    cat = unicodedata.category(c)
    if cat.startswith("P") or cat.startswith("S"):
        return True
    return False

def basic_tokenize(doc):
    doc_tokens = []
    char_to_word = []
    word_to_char_start = []
    prev_is_whitespace = True
    prev_is_punc = False
    prev_is_num = False
    for pos, c in enumerate(doc):
        if is_whitespace(c):
            prev_is_whitespace = True
            prev_is_punc = False
        else:
            if prev_is_whitespace or is_punctuation(c) or prev_is_punc or (prev_is_num and not str(c).isnumeric()):
                doc_tokens.append(c)
                word_to_char_start.append(pos)
            else:
                doc_tokens[-1] += c
            prev_is_whitespace = False
            prev_is_punc = is_punctuation(c)
            prev_is_num = str(c).isnumeric()
        char_to_word.append(len(doc_tokens) - 1)

    return doc_tokens, char_to_word, word_to_char_start

# %%
def get_schema(tables):
    schema, headers, colTypes, naturalMap = {}, {}, {}, {}
    for table in tables:
        values = [set() for _ in range(len(table["header"]))]
        for row in table["rows"]:
            for i, value in enumerate(row):
                values[i].add(str(value).lower())
        columns = {column: values[i] for i, column in enumerate(table["header"])}

        trans = {"text": "string", "real": "real", "integer": "integer"}
        colTypes[table["id"]] = {col:trans[ty.lower()] for ty, col in zip(table["types"], table["header"])}
        schema[table["id"]] = columns
        naturalMap[table["id"]] = {col: col for col in columns}
        headers[table["id"]] = table["header"]

    return schema, headers, colTypes, naturalMap


# if __name__ == "__main__":
#     data_path = os.path.join("WikiSQL", "data")
#     for phase in ["train", "dev", "test"]:
#         src_file = os.path.join(data_path, phase + ".jsonl")
#         schema_file = os.path.join(data_path, phase + ".tables.jsonl")
#         output_file = os.path.join("data", "wiki" + phase + ".jsonl")
#         schema, headers, colTypes, naturalMap = get_schema(utils.read_jsonl(schema_file))

# %%
from pathlib import Path

# data_path = Path().absolute().parent.parent / "data/sqldata/wikisql"
data_path = Path().absolute().parent / "src/data/train"
src_file = data_path / "train.jsonl"
schema_file = data_path / "train_table.jsonl"
output_file = data_path / "hydra_train.jsonl"
# schema, headers, colTypes, naturalMap = get_schema(read_jsonl(schema_file))

# %%
tables = read_jsonl(schema_file)

# %%
schema, headers, colTypes, naturalMap = {}, {}, {}, {}
for table in tables:
    values = [set() for _ in range(len(table["header"]))]
    for row in table["rows"]:
        for i, value in enumerate(row):
            values[i].add(str(value).lower())
    columns = {column: values[i] for i, column in enumerate(table["header"])}

    trans = {"text": "string", "real": "real", "integer": "integer"}
    colTypes[table["id"]] = {col: trans[ty.lower()] for ty, col in zip(table["types"], table["header"])}
    schema[table["id"]] = columns
    naturalMap[table["id"]] = {col: col for col in columns}
    headers[table["id"]] = table["header"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-8e44b0021251> in <module>
#       8
#       9     trans = {"text": "string", "real": "real", "integer": "integer"}
# ---> 10     colTypes[table["id"]] = {col:trans[ty.lower()] for ty, col in zip(table["types"], table["header"])}
#      11     schema[table["id"]] = columns
#      12     naturalMap[table["id"]] = {col: col for col in columns}
#
# <ipython-input-16-8e44b0021251> in <dictcomp>(.0)
#       8
#       9     trans = {"text": "string", "real": "real", "integer": "integer"}
# ---> 10     colTypes[table["id"]] = {col:trans[ty.lower()] for ty, col in zip(table["types"], table["header"])}
#      11     schema[table["id"]] = columns
#      12     naturalMap[table["id"]] = {col: col for col in columns}
#
# KeyError: 'timestamp'

# %%
table["header"]
# Out:
# ['index',
#  'Symbol',
#  'Market',
#  'Name',
#  'Sector',
#  'Industry',
#  'ListingDate',
#  'SettleMonth',
#  'Representative',
#  'HomePage',
#  'Region']

# %%
table["types"]
# Out:
# ['INTEGER',
#  'TEXT',
#  'TEXT',
#  'TEXT',
#  'TEXT',
#  'TEXT',
#  'TIMESTAMP',
#  'TEXT',
#  'TEXT',
#  'TEXT',
#  'TEXT']

# %%
columns.keys()
# Out:
# dict_keys(['index', 'Symbol', 'Market', 'Name', 'Sector', 'Industry', 'ListingDate', 'SettleMonth', 'Representative', 'HomePage', 'Region'])

# %%
for table in tables:
    values = [set() for _ in range(len(table["header"]))]
    for row in table["rows"]:
        for i, value in enumerate(row):
            values[i].add(str(value).lower())
    columns = {column: values[i] for i, column in enumerate(table["header"])}

    trans = {"text": "string", "real": "real", "integer": "integer"}
    colTypes[table["id"]] = {col:trans[ty.lower()] for ty, col in zip(table["types"], table["header"])}
    schema[table["id"]] = columns
    naturalMap[table["id"]] = {col: col for col in columns}
    headers[table["id"]] = table["header"]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-149fa1c4d834> in <module>
# ----> 1 for table in tables:
#       2     break
#
# NameError: name 'tables' is not defined

# %%
values = [set() for _ in range(len(table["header"]))]
for row in table["rows"]:
    for i, value in enumerate(row):
        values[i].add(str(value).lower())
columns = {column: values[i] for i, column in enumerate(table["header"])}

# %%
trans = {"text": "string", "real": "real", "integer": "integer"}
colTypes[table["id"]] = {col:trans[ty.lower()] for ty, col in zip(table["types"], table["header"])}

# %%
colTypes
# Out:
# {'1-1000181-1': {'State/territory': 'string',
#   'Text/background colour': 'string',
#   'Format': 'string',
#   'Current slogan': 'string',
#   'Current series': 'string',
#   'Notes': 'string'},
#  '1-10006830-1': {'Aircraft': 'string',
#   'Description': 'string',
#   'Max Gross Weight': 'string',
#   'Total disk area': 'string',
#   'Max disk Loading': 'string'},
#  '1-10007452-3': {'Order Year': 'string',
#   'Manufacturer': 'string',
#   'Model': 'string',
#   'Fleet Series (Quantity)': 'string',
#   'Powertrain (Engine/Transmission)': 'string',
#   'Fuel Propulsion': 'string'},
#  '1-10015132-1': {'Player': 'string',
#   'No.': 'string',
#   'Nationality': 'string',
#   'Position': 'string',
#   'Years in Toronto': 'string',
#   'School/Club Team': 'string'},
#  '1-10015132-14': {'Player': 'string',
#   'No.': 'real',
#   'Nationality': 'string',
#   'Position': 'string',
#   'Years in Toronto': 'string',
#   'School/Club Team': 'string'},
#  '1-10015132-2': {'Player': 'string',
#   'No.': 'string',
#   'Nationality': 'string',
#   'Position': 'string',
#   'Years in Toronto': 'string',
#   'School/Club Team': 'string'},
#  '1-10015132-21': {'Player': 'string',
#   'No.': 'real',
#   'Nationality': 'string',
#   'Position': 'string',
#   'Years in Toronto': 'string',
#   'School/Club Team': 'string'},
#  '1-10015132-3': {'Player': 'string',
#   'No.': 'real',
#   'Nationality': 'string',
#   'Position': 'string',
#   'Years in Toronto': 'string',
#   'School/Club Team': 'string'},
#  '1-10015132-7': {'Player': 'string',
#   'No.': 'real',
#   'Nationality': 'string',
#   'Position': 'string',
#   'Years in Toronto': 'string',
#   'School/Club Team': 'string'},
#  '1-10020178-1': {'Name': 'string',
#   'Canton': 'string',
#   'Height (meters)': 'real',
#   'Crest length (meters)': 'real',
#   'Type': 'string',
#   'Year of construction': 'real',
#   'Name of the Lake': 'string'},
#  '1-10021158-3': {'Year': 'real',
#   'Tournaments played': 'real',
#   'Cuts made*': 'real',
#   'Wins': 'real',
#   '2nd': 'real',
#   'Top 10s': 'real',
#   'Best finish': 'string',
#   'Earnings ($)': 'real',
#   'Money list rank': 'string',
#   'Scoring average': 'string',
#   'Scoring rank': 'string'},
#  '1-10023387-1': {'Player': 'string',
#   'Years Played': 'string',
#   'Total W-L': 'string',
#   'Singles W-L': 'string',
#   'Doubles W-L': 'string'},
#  '1-1004033-1': {'Season': 'real',
#   'Player': 'string',
#   'Position': 'string',
#   'Nationality': 'string',
#   'Team': 'string',
#   'Draft Pick #': 'string',
#   'Draft Class': 'string',
#   'College': 'string'},
#  '1-100518-1': {'Name': 'string',
#   'Direction': 'string',
#   'Mantra': 'string',
#   'Weapon': 'string',
#   'Consort': 'string',
#   'Graha (Planet)': 'string',
#   'Guardian Mātṛkā': 'string'},
#  '1-10054296-1': {'Member': 'string',
#   'Headquarters': 'string',
#   'Classification': 'string',
#   'Chapters': 'real',
#   'Founded': 'string',
#   'UCCFS': 'real'},
#  '1-1007688-1': {'Year': 'string',
#   'Typhus': 'real',
#   'Typhoid fever': 'real',
#   'Relapsing fever': 'real',
#   'Smallpox': 'real',
#   'Malaria': 'string'},
#  '1-10082596-1': {'School': 'string',
#   'Location': 'string',
#   'Founded': 'real',
#   'Affiliation': 'string',
#   'Enrollment': 'real',
#   'Team Nickname': 'string',
#   'Primary conference': 'string'},
#  '1-1008653-9': {'Country ( exonym )': 'string',
#   'Capital ( exonym )': 'string',
#   'Country ( endonym )': 'string',
#   'Capital ( endonym )': 'string',
#   'Official or native language(s) (alphabet/script)': 'string'},
#  '1-1009087-1': {'Season': 'string',
#   'Network': 'string',
#   'Season premiere': 'string',
#   'Season finale': 'string',
#   'TV season': 'string',
#   'Ranking': 'string',
#   'Viewers (in millions)': 'string'},
#  '1-10118412-6': {'State/Territory': 'string',
#   'Asian American Population (2010 Census)': 'real',
#   'Chinese': 'real',
#   'Filipino': 'real',
#   'Indian': 'real',
#   'Japanese': 'real',
#   'Korean': 'real',
#   'Vietnamese': 'real',
#   'Other Asian': 'real'},
#  '1-1011906-1': {'Regional County Municipality (RCM)': 'string',
#   'Population Canada 2011 Census': 'real',
#   'Land Area': 'string',
#   'Density (pop. per km2)': 'string',
#   'Seat of RCM': 'string'},
#  '1-101196-1': {'County': 'string',
#   'English name': 'string',
#   'Irish name': 'string',
#   'Population': 'real',
#   'Irish speakers': 'string'},
#  '1-10120207-8': {'Season': 'real',
#   'Timeslot ( ET )': 'string',
#   'Season premiere': 'string',
#   'Season finale': 'string',
#   'TV season': 'string',
#   'Rank': 'string',
#   'Viewers (millions)': 'string'},
#  '1-10121127-1': {'UN Operation name': 'string',
#   'UN Operation title': 'string',
#   'Location': 'string',
#   'Dates of Australian involvement': 'string',
#   'Number of Australians involved': 'string',
#   'Australian role': 'string'},
#  '1-1012730-1': {'Year': 'real',
#   'Starts': 'real',
#   'Wins': 'real',
#   'Top 5': 'real',
#   'Top 10': 'real',
#   'Poles': 'real',
#   'Avg. Start': 'string',
#   'Avg. Finish': 'string',
#   'Winnings': 'string',
#   'Position': 'string',
#   'Team(s)': 'string'},
#  '1-1012730-2': {'Year': 'real',
#   'Starts': 'real',
#   'Wins': 'real',
#   'Top 5': 'real',
#   'Top 10': 'real',
#   'Poles': 'real',
#   'Avg. Start': 'string',
#   'Avg. Finish': 'string',
#   'Winnings': 'string',
#   'Position': 'string',
#   'Team(s)': 'string'},
#  '1-10128185-2': {'Song': 'string',
#   'Mobiles': 'real',
#   'Northern Ireland': 'real',
#   'Northern England': 'real',
#   'Scotland': 'real',
#   'Southern England': 'real',
#   'Wales': 'real',
#   'Total': 'real'},
#  '1-1013129-1': {'Pick': 'real',
#   'Player': 'string',
#   'Position': 'string',
#   'Nationality': 'string',
#   'NHL team': 'string',
#   'College/junior/club team': 'string'},
#  '1-1013129-10': {'Pick': 'real',
#   'Player': 'string',
#   'Position': 'string',
#   'Nationality': 'string',
#   'NHL team': 'string',
#   'College/junior/club team': 'string'},
#  '1-1013129-11': {'Pick': 'real',
#   'Player': 'string',
#   'Position': 'string',
#   'Nationality': 'string',
#   'NHL team': 'string',
#   'College/junior/club team': 'string'},
#  '1-1013129-8': {'Pick': 'real',
#   'Player': 'string',
#   'Position': 'string',
#   'Nationality': 'string',
#   'NHL team': 'string',
#   'College/junior/club team': 'string'},
#  '1-1013168-2': {'State (class)': 'string',
#   'Vacator': 'string',
#   'Reason for change': 'string',
#   'Successor': 'string',
#   'Date of successors formal installation': 'string'},
#  '1-1013168-3': {'District': 'string',
#   'Vacator': 'string',
#   'Reason for change': 'string',
#   'Successor': 'string',
#   'Date successor seated': 'string'},
#  '1-101336-1': {'Formula': 'string',
#   'Notation': 'string',
#   'T c (K)': 'real',
#   'No. of Cu-O planes in unit cell': 'real',
#   'Crystal structure': 'string'},
#  '1-10138926-1': {'#': 'real',
#   'City': 'string',
#   '1981 Census': 'real',
#   '1991 Census': 'real',
#   '2001 Census': 'real',
#   '2010 Est.': 'real',
#   'Region': 'string'},
#  '1-1014319-1': {'Week': 'real',
#   'Dance/song': 'string',
#   'Horwood': 'string',
#   'Goodman': 'string',
#   'Dixon': 'string',
#   'Tonioli': 'string',
#   'Total': 'string',
#   'Result': 'string'},
#  '1-1015421-1': {'Class': 'string',
#   'Operator': 'string',
#   'No. Built': 'real',
#   'Year Built': 'string',
#   'Cars per Set': 'real',
#   'Unit nos.': 'string'},
#  '1-1015914-15': {'': 'string',
#   'Kalau Kawau Ya': 'string',
#   'Kawalgau Ya': 'string',
#   'Kalaw Lagaw Ya': 'string',
#   'Kulkalgau Ya': 'string',
#   'Kauraraigau Ya (Kowrareg)': 'string'},
#  '1-1015914-24': {'Case/Suffix': 'string',
#   'we two': 'string',
#   'you and I': 'string',
#   'you two': 'string',
#   'them two (the two)': 'string',
#   'who-two': 'string'},
#  '1-10160447-1': {'Position': 'real',
#   'Driver': 'string',
#   'Points': 'real',
#   'Winnings': 'string',
#   'Series': 'string'},
#  '1-101942-2': {'': 'string',
#   'All Children (000s)': 'real',
#   'Economically Active Children (000s)': 'real',
#   'Economically Active Children (%)': 'string',
#   'Child Labour (000s)': 'real',
#   'Child Labour (%)': 'string',
#   'Children In Hazardous Work (000s)': 'real',
#   'Children In Hazardous Work (%)': 'string'},
#  '1-10236830-1': {'Nomination': 'string',
#   'Actors Name': 'string',
#   'Film Name': 'string',
#   'Director': 'string',
#   'Country': 'string'},
#  '1-10236830-4': {'Nomination': 'string',
#   'Actors Name': 'string',
#   'Film Name': 'string',
#   'Director': 'string',
#   'Country': 'string'},
#  '1-10236830-6': {'Nomination': 'string',
#   'Actors Name': 'string',
#   'Film Name': 'string',
#   'Director': 'string',
#   'Country': 'string'},
#  '1-10240125-1': {'Season': 'string',
#   'Division': 'string',
#   'League Apps': 'real',
#   'League Goals': 'real',
#   'FA Cup Apps': 'real',
#   'FA Cup Goals': 'real',
#   'Total Apps': 'real',
#   'Total Goals': 'real'},
#  '1-10240125-2': {'Season': 'string',
#   'Division': 'string',
#   'League Apps': 'real',
#   'League Goals': 'real',
#   'FA Cup Apps': 'real',
#   'FA Cup Goals': 'real',
#   'Total Apps': 'real',
#   'Total Goals': 'real'},
#  '1-10262329-1': {'Assembly Type': 'string',
#   'Adhesive Type': 'string',
#   'Time(Sec)': 'string',
#   'Temp (°C)': 'string',
#   'Pressure': 'string'},
#  '1-10264179-2': {'Round': 'real',
#   'Circuit': 'string',
#   'Date': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Winning Driver': 'string',
#   'Winning Team': 'string'},
#  '1-10269427-3': {'Episode #': 'real',
#   'Production code': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Airdate': 'string'},
#  '1-1028356-3': {'Outcome': 'string',
#   'Year': 'real',
#   'Championship': 'string',
#   'Surface': 'string',
#   'Partner': 'string',
#   'Opponents': 'string',
#   'Score': 'string'},
#  '1-10284385-1': {'Begin Date': 'string',
#   'End Date': 'string',
#   'Representative': 'string',
#   'Date of birth': 'string',
#   'House term': 'string',
#   'State served': 'string',
#   'Party': 'string',
#   'Age (years, days)': 'string'},
#  '1-10295819-1': {'Player': 'string',
#   'Current singles ranking': 'string',
#   'Current doubles ranking': 'string',
#   'First year played': 'real',
#   'Ties played': 'real',
#   'Total W–L': 'string',
#   'Singles W–L': 'string',
#   'Doubles W–L': 'string'},
#  '1-103084-4': {'Year': 'real',
#   'Broadcast date': 'string',
#   'BBC One total viewing': 'real',
#   'BBC One Rank': 'string',
#   'BBC Two total viewing': 'string',
#   'BBC Two Rank': 'string'},
#  '1-10312547-1': {'Character': 'string',
#   '1954 Broadway': 'string',
#   '1955 broadcast': 'string',
#   '1960 broadcast': 'string',
#   '1979 Broadway': 'string',
#   '1990 Broadway': 'string',
#   '1991 Broadway': 'string',
#   '1998 Broadway': 'string',
#   '1999 Broadway': 'string'},
#  '1-10321124-1': {'↓ Function / Genus →': 'string',
#   'Shigella': 'string',
#   'Salmonella': 'string',
#   'Yersinia': 'string',
#   'Escherichia': 'string'},
#  '1-10321805-1': {'Year (Ceremony)': 'string',
#   'Film title used in nomination': 'string',
#   'Original title': 'string',
#   'Director': 'string',
#   'Result': 'string'},
#  '1-10335-1': {'Camp': 'string',
#   'Estimated deaths': 'string',
#   'Operational': 'string',
#   'Occupied territory': 'string',
#   'Current country of location': 'string',
#   'Primary means for mass killings': 'string'},
#  '1-10360656-1': {'Round': 'real',
#   'Choice': 'real',
#   'Overall': 'real',
#   'Player name': 'string',
#   'Position': 'string',
#   'College': 'string'},
#  '1-10360823-1': {'Round': 'real',
#   'Choice': 'real',
#   'Overall': 'real',
#   'Player name': 'string',
#   'Position': 'string',
#   'College': 'string'},
#  '1-10361230-1': {'Round': 'real',
#   'Choice': 'real',
#   'Overall': 'real',
#   'Player name': 'string',
#   'Position': 'string',
#   'College': 'string'},
#  '1-10361453-2': {'Game': 'real',
#   'Date': 'string',
#   'Opponent': 'string',
#   'Result': 'string',
#   'Vikings points': 'real',
#   'Opponents': 'real',
#   'Record': 'string',
#   'Attendance': 'real'},
#  '1-10361625-1': {'Round': 'real',
#   'Choice': 'real',
#   'Overall': 'real',
#   'Player name': 'string',
#   'Position': 'string',
#   'College': 'string'},
#  '1-1036189-1': {'Headstamp ID': 'string',
#   'Primer Annulus Color': 'string',
#   'Bullet Tip Color': 'string',
#   'Other Features': 'string',
#   'Functional Type': 'string'},
#  '1-1037590-1': {'Year': 'real',
#   'Games': 'real',
#   'Games started': 'real',
#   'Completions': 'real',
#   'Attempts': 'real',
#   'Completion %': 'string',
#   'Yards': 'real',
#   'Yards/Attempt': 'string',
#   'Touchdowns': 'real',
#   'Interceptions': 'real',
#   'Rating': 'string'},
#  '1-10392906-2': {'Week': 'real',
#   'Date': 'string',
#   'Kickoff': 'string',
#   'Opponent': 'string',
#   'Final score': 'string',
#   'Team record': 'string',
#   'Game site': 'string',
#   'Attendance': 'real'},
#  '1-10399701-2': {'School Year': 'string',
#   'Class A': 'string',
#   'Class AA': 'string',
#   'Class AAA': 'string',
#   'Class AAAA': 'string',
#   'Class AAAAA': 'string'},
#  '1-10402018-1': {'Character': 'string',
#   'Australia & New Zealand (Sydney - first run, Melbourne, Auckland)': 'string',
#   'London': 'string',
#   'Toronto / Broadway': 'string',
#   'Brazil': 'string',
#   'UK Tour': 'string',
#   'US Tour': 'string',
#   'Italy (Milan, Rome, Trieste)': 'string'},
#  '1-10413597-4': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Setting': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string'},
#  '1-10413597-5': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Setting': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'U.S. viewers (million)': 'string',
#   'Original air date': 'string'},
#  '1-10416547-1': {'Date': 'string',
#   'Album name': 'string',
#   'Track': 'string',
#   'Track title': 'string',
#   'Lyricist': 'string',
#   'Music genre/style': 'string',
#   'Major instrument(s)': 'string',
#   'Lyrics theme/style': 'string',
#   'Duration': 'string'},
#  '1-10420426-1': {'Season': 'string',
#   'Series': 'string',
#   'Team': 'string',
#   'Races': 'real',
#   'Wins': 'real',
#   'Poles': 'real',
#   'F/Laps': 'real',
#   'Podiums': 'real',
#   'Points': 'real',
#   'Position': 'string'},
#  '1-1046071-1': {'Year': 'real',
#   'Division': 'real',
#   'League': 'string',
#   'Regular Season': 'string',
#   'Playoffs': 'string',
#   'Open Cup': 'string'},
#  '1-1046454-1': {'Year': 'real',
#   'Division': 'real',
#   'League': 'string',
#   'Regular Season': 'string',
#   'Playoffs': 'string',
#   'Open Cup': 'string'},
#  '1-10470082-3': {'No.': 'real',
#   '#': 'real',
#   'Title': 'string',
#   'Director': 'string',
#   'Writer': 'string',
#   'US air date': 'string',
#   'Storyteller': 'string',
#   'Villains': 'string'},
#  '1-10470082-4': {'No.': 'real',
#   '#': 'real',
#   'Title': 'string',
#   'Director': 'string',
#   'Writer': 'string',
#   'US air date': 'string',
#   'Storyteller': 'string',
#   'Villains': 'string'},
#  '1-10470082-5': {'No.': 'real',
#   '#': 'real',
#   'Title': 'string',
#   'Director': 'string',
#   'Writer': 'string',
#   'US air date': 'string',
#   'Storyteller': 'string',
#   'Villains': 'string'},
#  '1-10470082-6': {'No.': 'real',
#   '#': 'real',
#   'Title': 'string',
#   'Director': 'string',
#   'Writer': 'string',
#   'US air date': 'string',
#   'Storyteller': 'string',
#   'Villains': 'string'},
#  '1-10470082-7': {'No.': 'real',
#   '#': 'real',
#   'Title': 'string',
#   'Director': 'string',
#   'Writer': 'string',
#   'US air date': 'string',
#   'Storyteller': 'string',
#   'Villains': 'string'},
#  '1-10470082-8': {'No.': 'real',
#   '#': 'real',
#   'Title': 'string',
#   'Director': 'string',
#   'Writer': 'string',
#   'US air date': 'string',
#   'Storyteller': 'string',
#   'Villains': 'string'},
#  '1-10477224-1': {'Sepal length': 'string',
#   'Sepal width': 'string',
#   'Petal length': 'string',
#   'Petal width': 'string',
#   'Species': 'string'},
#  '1-104858-1': {'Country': 'string',
#   'Membership (from 2010)': 'real',
#   'Name of member organization': 'string',
#   'Year current Scouting organization joined WOSM': 'string',
#   'Year member organization was founded': 'string',
#   'Admits boys/girls': 'string'},
#  '1-10494429-3': {'': 'string',
#   'case': 'string',
#   '1st person': 'string',
#   '2nd person': 'string',
#   'masculine': 'string',
#   'feminine': 'string',
#   'neuter': 'string'},
#  '1-10527215-3': {'Rd': 'real',
#   'Name': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Winning driver': 'string',
#   'Winning team': 'string',
#   'Report': 'string'},
#  '1-10528691-4': {'Model': 'real',
#   'Introduction': 'string',
#   'Discontinued': 'string',
#   'CPU Speed': 'string',
#   'Print resolution (DPI) Resolution is given in dots per inch (DPI)': 'string',
#   'Print speed (PPM)': 'string',
#   'Standard memory': 'string',
#   'Maximum memory': 'string'},
#  '1-1053802-1': {'Region/country': 'string',
#   'Local title': 'string',
#   'Network': 'string',
#   'Winners': 'string',
#   'Main presenters': 'string'},
#  '1-10556257-1': {'Season': 'string',
#   'Team': 'string',
#   'League Apps': 'real',
#   'League Goals': 'real',
#   'Cup Apps': 'real',
#   'Cup Goals': 'real'},
#  '1-10566855-1': {'Season': 'real',
#   'Premier': 'string',
#   'Runner-up': 'string',
#   'Score': 'string',
#   'Margin': 'real',
#   'Venue': 'string',
#   'Attendance': 'real'},
#  '1-10568553-1': {'County': 'string',
#   'Location': 'string',
#   'Street Names': 'string',
#   'Milepost': 'string',
#   'Roads Intersected': 'string',
#   'Notes': 'string'},
#  '1-1057262-1': {'Commodity': 'string',
#   '2001-02': 'real',
#   '2002-03': 'real',
#   '2003-04': 'real',
#   '2004-05': 'real',
#   '2005-06': 'real',
#   '2006-07': 'real'},
#  '1-1057316-1': {'Serial number': 'string',
#   'Wheel arrangement ( Whyte notation )': 'string',
#   'Build date': 'string',
#   'Operational owner(s)': 'string',
#   'Disposition': 'string'},
#  '1-10577579-2': {'Institution': 'string',
#   'Location': 'string',
#   'Mens Nickname': 'string',
#   'Womens Nickname': 'string',
#   'Founded': 'real',
#   'Type': 'string',
#   'Enrollment': 'real',
#   'Joined': 'string'},
#  '1-10577579-3': {'Institution': 'string',
#   'Location': 'string',
#   'Men’s Nickname': 'string',
#   'Women’s Nickname': 'string',
#   'Founded': 'real',
#   'Type': 'string',
#   'Enrollment': 'real',
#   'Joined': 'string',
#   'Left': 'string',
#   'Current Conference': 'string',
#   'Classification': 'string'},
#  '1-10580575-1': {'': 'real',
#   'Capita': 'string',
#   'Prim. energy': 'real',
#   'Production': 'real',
#   'Export': 'real',
#   'Electricity': 'real',
#   'CO 2 -emission': 'real'},
#  '1-10581768-2': {'Institution': 'string',
#   'Nickname': 'string',
#   'Location': 'string',
#   'Founded': 'real',
#   'Type': 'string',
#   'Enrollment': 'real'},
#  '1-10592536-8': {'Team': 'string',
#   'Outgoing manager': 'string',
#   'Manner of departure': 'string',
#   'Date of vacancy': 'string',
#   'Replaced by': 'string',
#   'Date of appointment': 'string',
#   'Position in table': 'string'},
#  '1-10595672-1': {'Date': 'string',
#   'Opponent': 'string',
#   'Home / Away': 'string',
#   'Score': 'string',
#   'High points': 'string',
#   'High rebounds': 'string',
#   'High assists': 'string',
#   'Location/Attendance': 'string',
#   'Record': 'string'},
#  '1-1059743-1': {'Rank': 'real',
#   'Member Association': 'string',
#   'Points': 'string',
#   'Group stage': 'real',
#   'Play-off': 'real',
#   'AFC Cup': 'real'},
#  '1-10602294-1': {'Name': 'string',
#   'Dates active': 'string',
#   'Peak classification': 'string',
#   'Windspeeds': 'string',
#   'Pressure': 'string',
#   'Areas affected': 'string',
#   'Damage (USD)': 'string',
#   'Deaths': 'string',
#   'Refs': 'string'},
#  '1-10610087-3': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string'},
#  '1-10610087-6': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string'},
#  '1-10621256-1': {'Player': 'string',
#   'Matches': 'real',
#   'Inns': 'real',
#   'N/O': 'real',
#   'Runs': 'real',
#   'High Score': 'real',
#   'Average': 'string',
#   '100': 'real',
#   '50': 'real',
#   'Catches': 'real',
#   'Stump': 'real'},
#  '1-106367-2': {'General election': 'real',
#   '# of candidates': 'real',
#   '# of seats won': 'real',
#   '% of popular vote': 'string',
#   'Result': 'string'},
#  '1-10646790-2': {'Week': 'real',
#   'Date': 'string',
#   'Opponent': 'string',
#   'Result': 'string',
#   'Stadium': 'string',
#   'Record': 'string',
#   'Attendance': 'real'},
#  '1-10647401-1': {'Week': 'real',
#   'Opponent': 'string',
#   'Result': 'string',
#   'Stadium': 'string',
#   'Record': 'string',
#   'Attendance': 'real'},
#  '1-10647639-1': {'Week': 'real',
#   'Date': 'string',
#   'Opponent': 'string',
#   'Result': 'string',
#   'Game site': 'string',
#   'Record': 'string',
#   'Attendance': 'real'},
#  '1-10650711-1': {'Pick #': 'real',
#   'NFL Team': 'string',
#   'Player': 'string',
#   'Position': 'string',
#   'College': 'string'},
#  '1-10664957-2': {'1st players choice': 'string',
#   '2nd players choice': 'string',
#   'Probability 1st player wins': 'string',
#   'Probability 2nd player wins': 'string',
#   'Probability of a draw': 'string'},
#  '1-1067134-1': {'DVD Name': 'string',
#   '# of Ep': 'real',
#   'Region 1': 'string',
#   'Region 2': 'string',
#   'Region 4': 'string'},
#  '1-1067441-1': {'Province': 'string',
#   'Population (2004 estimate)': 'real',
#   'Area (km²)': 'real',
#   'Density': 'string',
#   'GDP (2003, PPS in mil. € )': 'real',
#   'GDP per cap. (2003, in €)': 'real'},
#  '1-10701133-1': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Featured character(s)': 'string',
#   'Original air date': 'string',
#   'U.S. viewers (million)': 'string'},
#  '1-10705060-1': {'Season': 'string',
#   'Series': 'string',
#   'Team Name': 'string',
#   'Races': 'real',
#   'Poles': 'real',
#   'Wins': 'real',
#   'Points': 'real',
#   'Position': 'string'},
#  '1-10707142-2': {'Rnd': 'string',
#   'Race Name': 'string',
#   'Circuit': 'string',
#   'City/Location': 'string',
#   'Date': 'string',
#   'Pole position': 'string',
#   'Winning driver': 'string',
#   'Winning team': 'string',
#   'Report': 'string'},
#  '1-10710364-2': {'Religious group': 'string',
#   'Population %': 'string',
#   'Growth (1991–2001)': 'string',
#   'Sex ratio (total)': 'real',
#   'Literacy (%)': 'string',
#   'Work participation (%)': 'string',
#   'Sex ratio (rural)': 'real',
#   'Sex ratio (urban)': 'real',
#   'Sex ratio (child)': 'real'},
#  '1-10715317-2': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string',
#   'U.S. viewers (millions)': 'string'},
#  '1-10716893-3': {'Year': 'real',
#   'Network': 'string',
#   'Host': 'string',
#   'Pre-race analyst': 'string',
#   'Lap-by-lap': 'string',
#   'Color commentator(s)': 'string',
#   'Pit reporters': 'string'},
#  '1-10718192-2': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string',
#   'U.S. viewers (millions)': 'string'},
#  '1-10718525-2': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string',
#   'U.S. viewers (millions)': 'string'},
#  '1-10718631-2': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string',
#   'U.S. viewers (millions)': 'string'},
#  '1-10718984-2': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string',
#   'U.S. viewers (millions)': 'string'},
#  '1-10722506-6': {'Conference': 'string',
#   '# of Bids': 'real',
#   'Record': 'string',
#   'Win %': 'string',
#   'Round of 32': 'real',
#   'Sweet Sixteen': 'real',
#   'Elite Eight': 'real',
#   'Final Four': 'real',
#   'Championship Game': 'real'},
#  '1-10725629-2': {'Rnd': 'string',
#   'Race Name': 'string',
#   'Circuit': 'string',
#   'City/Location': 'string',
#   'Date': 'string',
#   'Pole position': 'string',
#   'Fastest lap': 'string',
#   'Winning driver': 'string',
#   'Winning team': 'string',
#   'Report': 'string'},
#  '1-10748727-1': {'Season': 'string',
#   'Series': 'string',
#   'Team Name': 'string',
#   'Races': 'real',
#   'Wins': 'real',
#   'Poles': 'real',
#   'F/Laps': 'real',
#   'Podiums': 'real',
#   'Points': 'string',
#   'Position': 'string'},
#  '1-10749143-2': {'Series #': 'real',
#   'Season #': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string',
#   'Production code': 'string',
#   'U.S. viewers (millions)': 'string'},
#  '1-10749367-3': {'#': 'real',
#   'Air Date': 'string',
#   'Challenge': 'string',
#   'Winner': 'string',
#   'Test-taker': 'string',
#   'Passed?': 'string'},
#  '1-10797463-1': {'Village (German)': 'string',
#   'Village (Slovenian)': 'string',
#   'Number of people 1991': 'real',
#   'Percent of Slovenes 1991': 'string',
#   'Percent of Slovenes 1951': 'string'},
#  '1-10798928-1': {'Year (Ceremony)': 'string',
#   'Film title used in nomination': 'string',
#   'Original title': 'string',
#   'Director': 'string',
#   'Result': 'string'},
#  '1-10812293-4': {'Game': 'real',
#   'Date': 'string',
#   'Team': 'string',
#   'Score': 'string',
#   'High points': 'string',
#   'High rebounds': 'string',
#   'High assists': 'string',
#   'Location Attendance': 'string',
#   'Record': 'string'},
#  '1-10812938-3': {'Pick #': 'real',
#   'CFL Team': 'string',
#   'Player': 'string',
#   'Position': 'string',
#   'College': 'string'},
#  '1-10812938-4': {'Pick #': 'real',
#   'CFL Team': 'string',
#   'Player': 'string',
#   'Position': 'string',
#   'College': 'string'},
#  '1-10812938-5': {'Pick #': 'real',
#   'CFL Team': 'string',
#   'Player': 'string',
#   'Position': 'string',
#   'College': 'string'},
#  '1-1081459-1': {'Number Range': 'string',
#   'Builder': 'string',
#   'Introduced': 'real',
#   'No. Built': 'real',
#   'Region': 'string',
#   'Withdrawn': 'real'},
#  '1-10815352-1': {'League': 'string',
#   'Sport': 'string',
#   'Country': 'string',
#   'Season': 'string',
#   'Games': 'real',
#   'Average attendance': 'real',
#   'Total attendance': 'real'},
#  '1-10818465-1': {'Model': 'string',
#   'RU': 'real',
#   'Max processors': 'string',
#   'Processor frequency': 'string',
#   'Max memory': 'string',
#   'Max disk capacity': 'string',
#   'GA Date': 'string'},
#  '1-10819266-8': {'Season': 'real',
#   'Episodes': 'real',
#   'Time slot (EST)': 'string',
#   'Season premiere': 'string',
#   'Season finale': 'string',
#   'TV season': 'string',
#   'Rank': 'string',
#   'Viewers (in millions)': 'string'},
#  '1-10842344-1': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string',
#   'Production code': 'string',
#   'U.S. viewers (millions)': 'string'},
#  '1-10874596-1': {'Year [e ] (Ceremony)': 'string',
#   'Film title used in nomination': 'string',
#   'Original title': 'string',
#   'Director': 'string',
#   'Result': 'string'},
#  '1-1087659-2': {'Year': 'string',
#   'Division': 'string',
#   'League': 'string',
#   'Reg. Season': 'string',
#   'Playoffs': 'string',
#   'Avg. Attendance': 'real'},
#  '1-10908676-7': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string'},
#  '1-10921309-1': {'': 'real',
#   'Capita': 'string',
#   'Prim. energy': 'real',
#   'Production': 'real',
#   'Export': 'real',
#   'Electricity': 'real',
#   'CO 2 -emission': 'string'},
#  '1-10932739-2': {'Planet': 'string',
#   'Planet Type': 'string',
#   'Semimajor Axis ( AU )': 'string',
#   'Orbital Period': 'string',
#   'Radial velocity (m/s)': 'string',
#   'Detectable by:': 'string'},
#  '1-10935548-1': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string',
#   'Production code': 'string',
#   'U.S. viewers (millions)': 'string'},
#  '1-10942714-1': {'Rank': 'real',
#   'English title': 'string',
#   'Chinese title': 'string',
#   'Average': 'real',
#   'Peak': 'real',
#   'Premiere': 'real',
#   'Finale': 'real',
#   'HK viewers': 'string'},
#  '1-10953197-2': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Director': 'string',
#   'Writer(s)': 'string',
#   'Original air date': 'string',
#   'Production code': 'string'},
#  '1-10953197-3': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Director': 'string',
#   'Writer(s)': 'string',
#   'Original air date': 'string',
#   'Production code': 'string'},
#  '1-10953197-4': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Director': 'string',
#   'Writer(s)': 'string',
#   'Original air date': 'string',
#   'Production code': 'string'},
#  '1-10953197-6': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Director': 'string',
#   'Writer(s)': 'string',
#   'Original air date': 'string',
#   'Production code': 'string'},
#  '1-10953197-7': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Director': 'string',
#   'Writer(s)': 'string',
#   'Original air date': 'string',
#   'Production code': 'string'},
#  '1-10960039-1': {'Pick #': 'real',
#   'CFL Team': 'string',
#   'Player': 'string',
#   'Position': 'string',
#   'College': 'string'},
#  '1-10960039-6': {'Pick #': 'real',
#   'CFL Team': 'string',
#   'Player': 'string',
#   'Position': 'string',
#   'College': 'string'},
#  '1-10966926-2': {'Round': 'real',
#   'Choice': 'real',
#   'Player name': 'string',
#   'Position': 'string',
#   'Height': 'string',
#   'Weight': 'real',
#   'College': 'string'},
#  '1-10975034-4': {'Pick #': 'real',
#   'CFL Team': 'string',
#   'Player': 'string',
#   'Position': 'string',
#   'College': 'string'},
#  '1-10975034-5': {'Pick #': 'real',
#   'CFL Team': 'string',
#   'Player': 'string',
#   'Position': 'string',
#   'College': 'string'},
#  '1-10979230-4': {'Romaji title': 'string',
#   'Japanese title': 'string',
#   'Release date': 'string',
#   'Reference': 'string',
#   'Oricon': 'real'},
#  '1-10979230-5': {'Romaji title': 'string',
#   'Japanese title': 'string',
#   'Release date': 'string',
#   'Reference': 'string',
#   'Oricon': 'real'},
#  '1-1099080-1': {'Condition': 'string',
#   'Prothrombin time': 'string',
#   'Partial thromboplastin time': 'string',
#   'Bleeding time': 'string',
#   'Platelet count': 'string'},
#  '1-11019212-1': {'Location': 'string',
#   'Monday': 'string',
#   'Tuesday': 'string',
#   'Wednesday': 'string',
#   'Thursday': 'string',
#   'Friday': 'string',
#   'Saturday': 'string',
#   'Sunday': 'string'},
#  '1-1104312-5': {'English name': 'string',
#   'Original name': 'string',
#   'Area in km²': 'string',
#   'Population at 2010 Census': 'real',
#   'Number of settlements and villages': 'real'},
#  '1-11056278-3': {'Rnd': 'real',
#   'Race Name': 'string',
#   'Pole position': 'string',
#   'Fastest lap': 'string',
#   'Winning driver': 'string',
#   'Winning team': 'string',
#   'Report': 'string'},
#  '1-11058032-1': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string',
#   'U.S. viewers (millions)': 'string'},
#  '1-11066073-1': {'Pilot car No.': 'real',
#   'Colour': 'string',
#   'Serial No.': 'string',
#   'Engine No.': 'real',
#   'Registration No.': 'string'},
#  '1-11071897-1': {'Interregnum began': 'string',
#   'Interregnum ended': 'string',
#   'Duration': 'string',
#   'Count Palatine of Saxony': 'string',
#   'Count Palatine of the Rhine': 'string'},
#  '1-11075747-4': {'Series #': 'real',
#   'Episode #': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string'},
#  '1-1108394-24': {'1973 Democratic initial primary': 'string',
#   'Manhattan': 'string',
#   'The Bronx': 'string',
#   'Brooklyn': 'string',
#   'Queens': 'string',
#   'Richmond [Staten Is.]': 'string',
#   'Total': 'real',
#   '%': 'string'},
#  '1-1108394-43': {'1932 (before recount)': 'string',
#   'party': 'string',
#   'Manhattan': 'string',
#   'The Bronx': 'string',
#   'Brooklyn': 'string',
#   'Queens': 'string',
#   'Richmond [Staten Is.]': 'string',
#   'Total': 'real',
#   '%': 'string'},
#  '1-11094950-1': {'Team': 'string',
#   'Location': 'string',
#   'Joined': 'real',
#   'Conference': 'string',
#   'Division': 'string',
#   'Previous Conference': 'string'},
#  '1-11111116-6': {'No. in season': 'real',
#   'No. in series': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string',
#   'U.S. viewers (million)': 'string'},
#  '1-11111116-7': {'No. in season': 'real',
#   'No. in series': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string',
#   'U.S. viewers (million)': 'string'},
#  '1-11111116-8': {'No. in season': 'real',
#   'No. in series': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string',
#   'U.S. viewers (million)': 'string'},
#  '1-1112176-1': {'Season': 'string',
#   'Division': 'string',
#   'League Apps (Sub)': 'real',
#   'League Goals': 'real',
#   'FA Cup Apps (Sub)': 'string',
#   'FA Cup Goals': 'real',
#   'FL Cup Apps (Sub)': 'real',
#   'FL Cup Goals': 'real',
#   'Other Apps': 'real',
#   'Other Goals': 'real',
#   'Total Apps (Sub)': 'string',
#   'Total Goals': 'real'},
#  '1-11129123-1': {'Episode Air Date': 'string',
#   'Audition City': 'string',
#   'Date': 'string',
#   'First Audition Venue': 'string',
#   'Callback Date': 'string',
#   'Callback Venue': 'string',
#   'Golden Tickets': 'real'},
#  '1-11147852-1': {'City of license/Market': 'string',
#   'Station': 'string',
#   'Channel TV ( DT )': 'string',
#   'Year of affiliation': 'string',
#   'Owned since': 'string'},
#  '1-11148572-1': {'Season': 'real',
#   'MLS Cup Winner': 'string',
#   'MLS Cup Runner-Up': 'string',
#   'MLS Supporters Shield Winner': 'string',
#   'MLS Supporters Shield Runner-Up': 'string'},
#  '1-11167610-1': {'Trim': 'string',
#   'Engine': 'string',
#   'Turbo': 'string',
#   'Fuel Delivery': 'string',
#   'Power': 'string',
#   'Torque': 'string',
#   'Transmission': 'string',
#   'Performance': 'string'},
#  '1-11173827-1': {'Rank': 'real',
#   'English title': 'string',
#   'Chinese title': 'string',
#   'Average': 'real',
#   'Peak': 'real',
#   'Premiere': 'real',
#   'Finale': 'real',
#   'HK viewers': 'string'},
#  '1-11178271-1': {'#': 'real',
#   'Episode': 'string',
#   'Air Date': 'string',
#   'Rating': 'string',
#   'Share': 'real',
#   '18–49 (Rating/Share)': 'string',
#   'Viewers (m)': 'string',
#   'Weekly Rank': 'real'},
#  '1-11190568-7': {'Team': 'string',
#   'Outgoing manager': 'string',
#   'Manner of departure': 'string',
#   'Date of vacancy': 'string',
#   'Replaced by': 'string',
#   'Date of appointment': 'string',
#   'Position': 'string'},
#  '1-11200856-1': {'Hand': 'string',
#   '1 credit': 'real',
#   '2 credits': 'real',
#   '3 credits': 'real',
#   '4 credits': 'real',
#   '5 credits': 'string'},
#  '1-11206787-5': {'Team': 'string',
#   'Stadium': 'string',
#   'Capacity': 'real',
#   'Highest': 'real',
#   'Lowest': 'real',
#   'Average': 'real'},
#  '1-11206916-2': {'Team': 'string',
#   'Outgoing manager': 'string',
#   'Manner of departure': 'string',
#   'Date of vacancy': 'string',
#   'Replaced by': 'string',
#   'Date of appointment': 'string'},
#  '1-11207040-5': {'Team': 'string',
#   'Stadium': 'string',
#   'Capacity': 'real',
#   'Highest': 'real',
#   'Lowest': 'real',
#   'Average': 'real'},
#  '1-11207040-6': {'Team': 'string',
#   'Outgoing manager': 'string',
#   'Manner of departure': 'string',
#   'Date of vacancy': 'string',
#   'Replaced by': 'string',
#   'Date of appointment': 'string'},
#  '1-11210576-3': {'Character': 'string',
#   'Position': 'string',
#   'Actor': 'string',
#   'First Episode': 'string',
#   'Final Episode': 'string',
#   'Duration': 'string',
#   'Final Episode Count': 'real'},
#  '1-11214212-1': {'Year': 'real',
#   'Numer of Jamaicans granted British citizenship': 'real',
#   'Naturalisation by residence': 'real',
#   'Naturalisation by marriage': 'real',
#   'Registration of a minor child': 'real',
#   'Registration by other means': 'real'},
#  '1-11214772-1': {'Year': 'string',
#   'Champion': 'string',
#   'Score': 'string',
#   'Runner-Up': 'string',
#   'Location': 'string',
#   'Semi-Finalist #1': 'string',
#   'Semi-Finalist #2': 'string'},
#  '1-11220799-2': {'Episode Titles': 'string',
#   'First air date': 'string',
#   'Reward': 'string',
#   'Immunity': 'string',
#   'Exiled': 'string',
#   'Eliminated': 'string',
#   'Vote': 'string',
#   'Finish': 'string'},
#  '1-11222744-2': {'Year': 'real',
#   'Title': 'string',
#   'Format': 'string',
#   'Studio': 'string',
#   'Release Date': 'string',
#   'Copyright Information': 'string',
#   'Catalog Number': 'string'},
#  '1-11230937-2': {'No. in series': 'real',
#   'No. in season': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Original air date': 'string',
#   'U.S. viewers (millions)': 'string'},
#  '1-11235334-2': {'#': 'real',
#   'Episode': 'string',
#   'Air Date': 'string',
#   'Timeslot': 'string',
#   'Viewers': 'string',
#   'Weekly Rank for Living': 'string'},
#  '1-11236195-2': {'Season': 'real',
#   'Grand FinalDate': 'string',
#   'WinningTeam': 'string',
#   'Score': 'string',
#   'LosingTeam': 'string',
#   'Location': 'string',
#   'GF Attendance': 'real',
#   'Clive Churchill Medal': 'string'},
#  '1-11236195-5': {'Season': 'real',
#   'Grand FinalDate': 'string',
#   'WinningTeam': 'string',
#   'Score': 'string',
#   'LosingTeam': 'string',
#   'Location': 'string',
#   'GF Attendance': 'real',
#   'Clive Churchill Medal': 'string'},
#  '1-1123802-1': {'Engine': 'string',
#   'Power, continuous': 'string',
#   'Critical altitude This is the highest altitude at which the engine can achieve its full continuous power rating. Above this altitude, power falls off with height as with a naturally aspirated engine . See Supercharger#Altitude effects for details.': 'string',
#   'Power, takeoff': 'string',
#   'Compression ratio': 'string',
#   'Supercharger gear ratio': 'string',
#   'Octane rating': 'string',
#   'Dry weight': 'string'},
#  '1-11240028-1': {'Character': 'string',
#   'Portrayed by': 'string',
#   'First appearance': 'string',
#   'Last appearance': 'string',
#   'Duration': 'string',
#   'Episodes': 'string'},
#  '1-11240028-3': {'Character': 'string',
#   'Portrayed by': 'string',
#   'Relationship': 'string',
#   'First appearance': 'string',
#   'Last appearance': 'string'},
#  '1-11244302-1': {'#': 'real',
#   'Episode': 'string',
#   'Air Date': 'string',
#   'Time slot (EST)': 'string',
#   'Rating': 'string',
#   'Share': 'real',
#   '18-49 (Rating/Share)': 'string',
#   'Viewers (m)': 'string',
#   'Rank (Overall)': 'string'},
#  '1-11250-4': {'Club': 'string',
#   'Position in 2012–13': 'string',
#   'First season in top division': 'string',
#   'Number of seasons in top division': 'real',
#   'Number of seasons in the Premier League': 'real',
#   'First season of current spell in top division': 'string',
#   'Top division titles': 'real',
#   'Last top division title': 'string'},
#  '1-11251109-3': {'#': 'real',
#   'Episode': 'string',
#   'Air Date': 'string',
#   'Timeslot (EST)': 'string',
#   'Season': 'string',
#   'Rating': 'string',
#   'Share': 'real',
#   '18–49': 'string',
#   'Viewers (m)': 'string',
#   'Rank (#)': 'string'},
#  '1-11251601-2': {'Country': 'string',
#   'Carbon dioxide emissions per year (10 6 Tons) (2006)': 'real',
#   'Percentage of global total': 'string',
#   'Avg. emission per km 2 of its land (tons)': 'real',
#   'Carbon dioxide emissions per year (Tons per person) (2007)': 'string'},
#  '1-11253290-2': {'#': 'real',
#   'Episode': 'string',
#   'Rating': 'string',
#   'Share': 'real',
#   'Rating/Share (18-49)': 'string',
#   'Viewers (millions)': 'string',
#   'Rank (timeslot)': 'real',
#   'Rank (night)': 'real',
#   'Rank (week)': 'string'},
#  '1-11254821-2': {'Finishing position': 'string',
#   'Points awarded (Platinum)': 'real',
#   'Points awarded (Gold)': 'real',
#   'Points awarded (Silver)': 'real',
#   'Points awarded (Satellite)': 'real'},
#  '1-11256021-1': {'Date': 'string',
#   'Founder': 'string',
#   'Extroversion Scales': 'string',
#   'People-task orientation scale': 'string',
#   'Introverted, Task-Oriented': 'string',
#   'Extroverted, Task-Oriented': 'string',
#   'Extroverted, Relationship-Oriented': 'string',
#   'Introverted, Relationship Oriented': 'string',
#   'Moderate': 'string'},
#  '1-11274401-2': {'No.': 'real',
#   'Episode': 'string',
#   'Air Date': 'string',
#   'Timeslot': 'string',
#   'Rating': 'string',
#   'Share': 'real',
#   '18–49 (Rating/Share)': 'string',
#   'Viewers (m)': 'string',
#   'Rank (#)': 'string'},
#  '1-11274401-3': {'No.': 'real',
#   'Episode': 'string',
#   'Air Date': 'string',
#   'Timeslot': 'string',
#   'Rating': 'string',
#   'Share': 'string',
#   '18–49 (Rating/Share)': 'string',
#   'Viewers (m)': 'string',
#   'Rank (#)': 'string'},
#  '1-11303072-5': {'Wicket': 'string',
#   'Runs': 'string',
#   'Batting partners': 'string',
#   'Batting team': 'string',
#   'Fielding team': 'string',
#   'Venue': 'string',
#   'Season': 'string'},
#  '1-11303072-9': {'Rank': 'real',
#   'Dismissals': 'real',
#   'Player': 'string',
#   'Nationality': 'string',
#   'Catches': 'real',
#   'Stumpings': 'real',
#   'Career Span': 'string'},
#  '1-1130632-1': {'No. in series': 'real',
#   'Title': 'string',
#   'Directed by': 'string',
#   'Written by': 'string',
#   'Featured character(s)': 'string',
#   'Original air date': 'string',
#   'U.S. viewers (million)': 'string'},
#  '1-1131183-2': {'Rank ( WJC )': 'real',
#   'Rank (ARDA)': 'real',
#   'Metro area': 'string',
#   'Number of Jews (WJC)': 'real',
#   'Number of Jews (ASARB)': 'real'},
#  '1-11318462-29': {'School': 'string',
#   'Location': 'string',
#   'Enrolment': 'real',
#   'Founded': 'real',
#   'Denomination': 'string',
#   'Day/Boarding': 'string',
#   'School Colours': 'string',
#   'Abbreviation': 'string',
#   'In competition since': 'real'},
#  '1-11318462-5': {'Crew': 'real',
#   'Open 1st VIII': 'string',
#   'Open 2nd VIII': 'string',
#   'Open 3rd VIII': 'string',
#   'U16 1st VIII': 'string',
#   'U16 2nd VIII': 'string',
#   'U16 3rd VIII': 'string',
#   'U15 1st IV': 'string',
#   'U15 2nd IV': 'string',
#   'U15 3rd IV': 'string',
#   'U15 4th IV': 'string',
#   'U15 5th IV': 'string',
#   'U15 6th IV': 'string'},
#  '1-1132568-3': {'Rd.': 'real',
#   'Grand Prix': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Winning Driver': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1132588-3': {'Rd.': 'real',
#   'Grand Prix': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Winning Driver': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-11326124-3': {'Edition': 'real',
#   'Zone': 'string',
#   'Round': 'string',
#   'Date': 'string',
#   'Against': 'string',
#   'Surface': 'string',
#   'Opponent': 'string',
#   'Outcome': 'string',
#   'Result': 'string'},
#  '1-11354111-3': {'#': 'real',
#   'Episode': 'string',
#   'Air Date': 'string',
#   'Rating': 'string',
#   'Share': 'real',
#   'Rating/Share 18–49': 'string',
#   'Viewers (m)': 'string',
#   'Timeslot Rank': 'real',
#   'Night Rank': 'string',
#   'Overall Rank': 'real'},
#  '1-1137142-1': {'Season': 'string',
#   'Group A Winner': 'string',
#   'Group B Winner': 'string',
#   'Group C Winner': 'string',
#   'Group D Winner': 'string'},
#  '1-1137695-3': {'Round': 'real',
#   'Grand Prix': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Winning Driver': 'string',
#   'Winning Constructor': 'string',
#   'Report': 'string'},
#  '1-1137704-2': {'Round': 'real',
#   'Grand Prix': 'string',
#   'Date': 'string',
#   'Location': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Winning Driver': 'string',
#   'Winning Constructor': 'string',
#   'Report': 'string'},
#  '1-1137707-2': {'Round': 'real',
#   'Grand Prix': 'string',
#   'Date': 'string',
#   'Location': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Winning Driver': 'string',
#   'Winning Constructor': 'string',
#   'Report': 'string'},
#  '1-1137718-2': {'Rd.': 'real',
#   'Grand Prix': 'string',
#   'Date': 'string',
#   'Location': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Winning Driver': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-11381701-3': {'Source': 'string',
#   'Date': 'string',
#   'Method': 'string',
#   'iOS': 'string',
#   'Android': 'string',
#   'BlackBerry': 'string',
#   'Symbian / Series 40': 'string',
#   'Bada': 'string',
#   'Windows': 'string',
#   'Other': 'string'},
#  '1-11390711-4': {'English Name': 'string',
#   'Japanese orthography': 'string',
#   'Pronouciation': 'string',
#   'abbreviation': 'string',
#   'Provider(IAI)': 'string',
#   'Foundation': 'real'},
#  '1-1139087-2': {'Rd.': 'real',
#   'Grand Prix': 'string',
#   'Date': 'string',
#   'Location': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Winning Driver': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-11391954-3': {'Country': 'string',
#   'Total': 'real',
#   'Marathon (mens)': 'real',
#   'Marathon (womens)': 'real',
#   'Half Marathon (mens)': 'real',
#   'Half Marathon (womens)': 'real'},
#  '1-1139835-1': {'Year': 'real',
#   'Winners': 'string',
#   'Grand Finalist': 'string',
#   'Scores': 'string',
#   'Venue': 'string',
#   'Crowd': 'real',
#   'Margin': 'real',
#   'Season Result': 'string'},
#  '1-1139835-3': {'Year': 'real',
#   'Winners': 'string',
#   'Grand Finalist': 'string',
#   'Scores': 'string',
#   'Venue': 'string',
#   'Crowd': 'real',
#   'Margin': 'real',
#   'Season Result': 'string'},
#  '1-1139835-9': {'Season': 'real',
#   'Premier': 'string',
#   'Runner Up': 'string',
#   'Score': 'string',
#   'Venue': 'string',
#   'Attendance': 'real',
#   'Premiership': 'string'},
#  '1-1140067-2': {'Rnd': 'real',
#   'Race': 'string',
#   'Date': 'string',
#   'Location': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Race Winner': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1140073-2': {'Rnd': 'real',
#   'Race': 'string',
#   'Date': 'string',
#   'Location': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Race Winner': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1140074-2': {'Rnd': 'real',
#   'Race': 'string',
#   'Date': 'string',
#   'Location': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Race Winner': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1140076-2': {'Rnd': 'real',
#   'Race': 'string',
#   'Date': 'string',
#   'Location': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Race Winner': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1140077-2': {'Rnd': 'real',
#   'Race': 'string',
#   'Date': 'string',
#   'Location': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Race Winner': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1140080-2': {'Rnd': 'real',
#   'Race': 'string',
#   'Date': 'string',
#   'Location': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Race Winner': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1140083-2': {'Rnd': 'real',
#   'Race': 'string',
#   'Date': 'string',
#   'Location': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Race Winner': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1140085-2': {'Rnd': 'real',
#   'Race': 'string',
#   'Date': 'string',
#   'Location': 'string',
#   'Pole Position': 'string',
#   'Fastest Lap': 'string',
#   'Race Winner': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1140088-6': {'Race Name': 'string',
#   'Circuit': 'string',
#   'Date': 'string',
#   'Winning driver': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1140090-6': {'Race Name': 'string',
#   'Circuit': 'string',
#   'Date': 'string',
#   'Winning driver': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1140103-6': {'#': 'real',
#   'Race Name': 'string',
#   'Circuit': 'string',
#   'Date': 'string',
#   'Winning driver': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1140105-6': {'Race Name': 'string',
#   'Circuit': 'string',
#   'Date': 'string',
#   'Winning driver': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1140111-5': {'Race Name': 'string',
#   'Circuit': 'string',
#   'Date': 'string',
#   'Winning driver': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1140113-5': {'Race Name': 'string',
#   'Circuit': 'string',
#   'Date': 'string',
#   'Winning driver': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1140116-5': {'Race Name': 'string',
#   'Circuit': 'string',
#   'Date': 'string',
#   'Winning driver': 'string',
#   'Constructor': 'string',
#   'Report': 'string'},
#  '1-1140117-5': {'Race Name': 'string',
#   'Circuit': 'string',
# ...
#   'Representative 3': 'string',
#   'Representative 4': 'string',
#   'Representative 5': 'string'},
#  '1-13939267-1': {'': 'real',
#   'Representative 1': 'string',
#   'Representative 2': 'string',
#   'Representative 3': 'string',
#   'Representative 4': 'string',
#   'Representative 5': 'string',
#   'Representative 6': 'string',
#   'Representative 7': 'string'},
#  '1-13940275-5': {'Club': 'string',
#   'Played': 'string',
#   'Won': 'string',
#   'Drawn': 'string',
#   'Lost': 'string',
#   'Points for': 'string',
#   'Points against': 'string',
#   'Tries for': 'string',
#   'Tries against': 'string',
#   'Try bonus': 'string',
#   'Losing bonus': 'string',
#   'Points': 'string'},
#  '1-13943239-1': {'Episode': 'string',
#   'Original Air Date': 'string',
#   'Viewers (millions)': 'string',
#   'Presenter': 'string',
#   'Location': 'string'},
#  '1-13956521-2': {'#': 'real',
#   'Episode title': 'string',
#   'Writer(s)': 'string',
#   'Director': 'string',
#   'Prod. Code': 'string',
#   'Original airdate': 'string'},
#  '1-13967239-2': {'SUBJECT': 'string',
#   'FRESHMAN (Grade 7)': 'string',
#   'SOPHOMORE (Grade 8)': 'string',
#   'JUNIOR (3rd Year)': 'string',
#   'SENIOR (4th Year)': 'string'},
#  '1-13981938-1': {'Grand Cru': 'string',
#   'Region': 'string',
#   'Village': 'string',
#   'Wine style': 'string',
#   'Vineyard surface (2010)': 'string'},
#  '1-13998897-1': {'Call sign': 'string',
#   'Frequency MHz': 'string',
#   'City of license': 'string',
#   'ERP W': 'real',
#   'Height m ( ft )': 'string',
#   'FCC info': 'string',
#   'Notes': 'string'},
#  '1-1399994-2': {'Outcome': 'string',
#   'Year': 'real',
#   'Championship': 'string',
#   'Surface': 'string',
#   'Partner': 'string',
#   'Opponents': 'string',
#   'Score': 'string'},
#  '1-14003108-1': {'Team': 'string',
#   'Stadium': 'string',
#   'Capacity': 'real',
#   'Highest': 'real',
#   'Lowest': 'real',
#   'Average': 'real'},
#  '1-14006-1': {'Condition': 'string',
#   'Prothrombin time': 'string',
#   'Partial thromboplastin time': 'string',
#   'Bleeding time': 'string',
#   'Platelet count': 'string'},
#  '1-14009909-1': {'District': 'string',
#   'Counties Represented': 'string',
#   'Delegate': 'string',
#   'Party': 'string',
#   'First Elected': 'real',
#   'Committee': 'string'},
#  '1-14015965-1': {'Previous season': 'string',
#   'Team': 'string',
#   'Town': 'string',
#   'Arena (capacity)': 'string',
#   'Website': 'string',
#   'Head Coach': 'string',
#   'Foreign Players (max. 2)': 'string'},
#  '1-14016079-1': {'Rd.': 'real',
#   'Race Title': 'string',
#   'Circuit': 'string',
#   'City / State': 'string',
#   'Date': 'string',
#   'Winner': 'string',
#   'Team': 'string',
#   'Report': 'string'},
#  '1-1402270-1': {'Year': 'real',
#   'Player Name': 'string',
#   'NFL Team': 'string',
#   'Position': 'string',
#   'Team Defense Rank': 'real',
#   'Team Performance': 'string'},
#  '1-1404414-2': {'Code': 'real',
#   'County': 'string',
#   'Former Province': 'string',
#   'Area (km 2 )': 'string',
#   'Population Census 2009': 'real',
#   'Capital': 'string'},
#  '1-1404456-1': {'Code': 'real',
#   'County': 'string',
#   'Former Province': 'string',
#   'Area (km 2 )': 'string',
#   'Population Census 2009': 'real',
#   'Capital': 'string'},
#  '1-14048996-1': {'': 'real',
#   'Capita': 'real',
#   'Prim. energy': 'string',
#   'Production': 'real',
#   'Import': 'real',
#   'Electricity': 'real',
#   'CO 2 -emission': 'real'},
#  '1-14049003-1': {'': 'real',
#   'Capita': 'string',
#   'Prim. energy': 'real',
#   'Production': 'real',
#   'Export': 'real',
#   'Electricity': 'string',
#   'CO 2 -emission': 'string'},
#  '1-14049026-1': {'': 'real',
#   'Capita': 'string',
#   'Prim. energy': 'real',
#   'Production': 'real',
#   'Export': 'real',
#   'Electricity': 'string',
#   'CO 2 -emission': 'real'},
#  '1-1404984-1': {'Call sign': 'string',
#   'Analog channel': 'string',
#   'Digital channel': 'string',
#   'Virtual channel': 'string',
#   'Network': 'string',
#   'Station Ownership': 'string'},
#  '1-1405704-1': {'Season': 'real',
#   'Race Name': 'string',
#   'Winning Driver': 'string',
#   'Chassis': 'string',
#   'Engine': 'string',
#   'Tires': 'string',
#   'Team': 'string'},
#  '1-14058433-3': {'Club': 'string',
#   'Played': 'string',
#   'Won': 'string',
#   'Drawn': 'string',
#   'Lost': 'string',
#   'Points for': 'string',
#   'Points against': 'string',
#   'Tries for': 'string',
#   'Tries against': 'string',
#   'Try bonus': 'string',
#   'Losing bonus': 'string',
#   'Points': 'string'},
#  '1-14058433-4': {'Club': 'string',
#   'Played': 'string',
#   'Won': 'string',
#   'Drawn': 'string',
#   'Lost': 'string',
#   'Points for': 'string',
#   'Points against': 'string',
#   'Tries for': 'string',
#   'Tries against': 'string',
#   'Try bonus': 'string',
#   'Losing bonus': 'string',
#   'Points': 'string'},
#  '1-14058433-5': {'Club': 'string',
#   'Played': 'string',
#   'Won': 'string',
#   'Drawn': 'string',
#   'Lost': 'string',
#   'Points for': 'string',
#   'Points against': 'string',
#   'Tries for': 'string',
#   'Tries against': 'string',
#   'Try bonus': 'string',
#   'Losing bonus': 'string',
#   'Points': 'string'},
#  '1-14070062-4': {'Club': 'string',
#   'Played': 'string',
#   'Won': 'string',
#   'Drawn': 'string',
#   'Lost': 'string',
#   'Points for': 'string',
#   'Points against': 'string',
#   'Tries for': 'string',
#   'Tries against': 'string',
#   'Try bonus': 'string',
#   'Losing bonus': 'string',
#   'Points': 'string'},
#  '1-1408397-3': {'#': 'real',
#   'Sanskrit संस्कृतम्': 'string',
#   'Tamil தமிழ்': 'string',
#   'Telugu తెలుగు': 'string',
#   'Kannada ಕನ್ನಡ': 'string',
#   'Malayalam മലയാളം': 'string',
#   'Mongolian': 'string'},
#  '1-14098-1': {'Country or territory with flag': 'string',
#   'Area (km²) (per sqmi)': 'string',
#   'Population (July 2009 est.)': 'real',
#   'Population density per km²': 'string',
#   'Capital': 'string'},
#  '1-1410384-1': {'Character Name': 'string',
#   'Voice Actor (Japanese)': 'string',
#   'Voice Actor (English 1997 / Saban)': 'string',
#   'Voice Actor (English 1998 / Pioneer)': 'string',
#   'Voice Actor (English 2006 / FUNimation)': 'string'},
#  '1-14115168-4': {'School': 'string',
#   'Mascot': 'string',
#   'Conference': 'string',
#   'National Titles': 'real',
#   'Founded': 'real'},
#  '1-14118521-1': {'EDO Flight': 'real',
#   'Shuttle': 'string',
#   'Mission': 'string',
#   'Launch Date': 'string',
#   'Duration': 'string',
#   'Primary Payload(s)': 'string'},
#  '1-14123513-5': {'Year': 'real',
#   '1st District': 'string',
#   '2nd District': 'string',
#   '3rd District': 'string',
#   '4th District': 'string',
#   '5th District': 'string'},
#  '1-14132239-3': {'Month': 'string',
#   'Week': 'real',
#   'Overall': 'string',
#   'Offensive': 'string',
#   'Defensive': 'string',
#   'Transition': 'string',
#   'Rookie': 'string'},
#  '1-14139408-1': {'Season': 'real',
#   'Class': 'string',
#   'Team': 'string',
#   'Motorcycle': 'string',
#   'Type': 'string',
#   'Races': 'real',
#   'Wins': 'real',
#   'Podiums': 'real',
#   'Poles': 'real',
#   'Fastest Laps': 'real',
#   'Pts': 'string',
#   'Position': 'string'},
#  '1-1414702-3': {'High School': 'string',
#   'Type': 'string',
#   'Established': 'real',
#   'Enrollment': 'real',
#   'Mascot': 'string',
#   'WIAA Classification': 'string',
#   'Notes': 'string'},
#  '1-1414743-1': {'School Name': 'string',
#   'City': 'string',
#   'Students': 'real',
#   'FTE Teachers': 'string',
#   'Pupil/Teacher Ratio': 'string',
#   'School Level': 'string',
#   'Low Grade': 'string',
#   'High Grade': 'string'},
#  '1-14152577-1': {'': 'string',
#   'ODM': 'real',
#   'NARC ODM-affiliated': 'real',
#   'PNU': 'real',
#   'PNU-affiliated': 'real',
#   'KANU PNU-affiliated': 'real',
#   'ODM-Kenya': 'real',
#   'Unaffiliated': 'real',
#   'Total': 'real',
#   'Vacant': 'real'},
#  '1-14158567-1': {'Member-elect': 'string',
#   'Party': 'string',
#   'District': 'string',
#   'Election date': 'string',
#   'Congress': 'string',
#   'Reason for non-seating': 'string'},
#  '1-14160327-4': {'Song title': 'string',
#   'Artist': 'string',
#   'Language': 'string',
#   'Decade': 'string',
#   'Genre': 'string',
#   'Exportable': 'string',
#   'Family Friendly': 'string'},
#  '1-1416612-1': {'State': 'string',
#   'Highest point': 'string',
#   'Highest elevation': 'string',
#   'Lowest point': 'string',
#   'Lowest elevation': 'string',
#   'Mean elevation': 'string'},
#  '1-142161-1': {'Cast': 'string',
#   '1951 ( BBC )': 'string',
#   '1957 (BBC)': 'string',
#   '1968 (BBC)': 'string',
#   '1970 (film)': 'string',
#   '2000 ( Carlton Television )': 'string'},
#  '1-14219514-1': {'Home (1st leg)': 'string',
#   'Home (2nd leg)': 'string',
#   '1st Leg': 'string',
#   '2nd leg': 'string',
#   'Aggregate': 'string'},
#  '1-14219514-2': {'Home (1st leg)': 'string',
#   'Home (2nd leg)': 'string',
#   '1st Leg': 'string',
#   '2nd leg': 'string',
#   'Aggregate': 'string'},
#  '1-14225409-1': {'Year': 'real',
#   'League': 'string',
#   'Reg. Season': 'string',
#   'Playoffs': 'string',
#   'US Open Cup': 'string',
#   'Avg. Attendance': 'real'},
#  '1-14240688-1': {'Year': 'real',
#   'Division': 'real',
#   'League': 'string',
#   'Regular Season': 'string',
#   'Playoffs': 'string',
#   'Open Cup': 'string',
#   'Avg. Attendance': 'real'},
#  '1-14245-3': {'s Car plate (starting 1937)': 'string',
#   'Voivodeship or city': 'string',
#   'Capital': 'string',
#   'Area (1930) in 1,000skm 2': 'string',
#   'Population (1931) in 1,000s': 'string'},
#  '1-14249278-1': {'Bit 15': 'real',
#   'Bits 14-12': 'real',
#   'Bits 11-0': 'string',
#   'Mnemonic': 'string',
#   'Description': 'string'},
#  '1-14254419-3': {'Elementary Schools': 'string',
#   'Mascot': 'string',
#   'Address': 'string',
#   'Principal (2013-2014)': 'string',
#   'Assistant Principal (2013-2014)': 'string'},
#  '1-142573-1': {'Designation': 'string',
#   'Bus width (bits)': 'real',
#   'Channels': 'string',
#   'Clock rate (MHz)': 'real',
#   'Bandwidth (MB/s)': 'real'},
#  '1-1425948-1': {'Chassis Manufacturer': 'string',
#   'Chassis Model': 'string',
#   'Body Model': 'string',
#   'Number in Fleet': 'real',
#   'Fleet Numbers': 'string'},
#  '1-1425958-1': {'Name': 'string',
#   '2011 Census': 'real',
#   '2006 Census': 'real',
#   '% change': 'string',
#   'Land area (km²)': 'string',
#   'Density (pop/km²)': 'string',
#   'Population rank': 'real'},
#  '1-14263158-3': {'Competition': 'string',
#   'Stage': 'string',
#   'Result': 'string',
#   'Opponent': 'string',
#   'Position': 'string',
#   'Scorers': 'string'},
#  '1-14288212-1': {'Team': 'string',
#   'First Played': 'real',
#   'Played': 'real',
#   'Win': 'real',
#   'Draw': 'real',
#   'Loss': 'real',
#   'Points For': 'real',
#   'Ponts Against': 'real',
#   'Last Meeting': 'real'},
#  '1-142950-1': {'Institution': 'string',
#   'Location': 'string',
#   'Established': 'real',
#   'Gained university status': 'real',
#   'Vice-chancellor': 'string',
#   'Total Number of Students': 'real',
#   'Research Funding (£,000)': 'real'},
#  '1-1429629-1': {'Episode': 'string',
#   'Broadcast date': 'string',
#   'Run time': 'string',
#   'Viewers (in millions)': 'string',
#   'Archive': 'string'},
#  '1-14308895-2': {'Country/Territory': 'string',
#   'Former pageant': 'string',
#   'Last competed': 'real',
#   'New pageant': 'string',
#   'Franchise since': 'real'},
#  '1-14310205-1': {'Team': 'string',
#   'Intercontinental': 'string',
#   'Recopa 1996': 'string',
#   'Supercopa 1996': 'string',
#   'CONMEBOL 1996': 'string',
#   'Copa Libertadores 1997': 'string'},
#  '1-14312471-1': {'Home team': 'string',
#   'Home team score': 'string',
#   'Away team': 'string',
#   'Away team score': 'string',
#   'Ground': 'string',
#   'Crowd': 'real',
#   'Date': 'string',
#   'Report': 'string'},
#  '1-14312471-3': {'Home team': 'string',
#   'Home team score': 'string',
#   'Away team': 'string',
#   'Away team score': 'string',
#   'Ground': 'string',
#   'Crowd': 'real',
#   'Date': 'string',
#   'Report': 'string'},
#  '1-14312471-4': {'Home team': 'string',
#   'Home team score': 'string',
#   'Away team': 'string',
#   'Away team score': 'string',
#   'Ground': 'string',
#   'Crowd': 'real',
#   'Date': 'string',
#   'Report': 'string'},
#  '1-14312471-7': {'Home team': 'string',
#   'Home team score': 'string',
#   'Away team': 'string',
#   'Away team score': 'string',
#   'Ground': 'string',
#   'Crowd': 'real',
#   'Date': 'string',
#   'Report': 'string'},
#  '1-1431450-4': {'District': 'string',
#   'Incumbent': 'string',
#   'Party': 'string',
#   'First elected': 'real',
#   'Result': 'string',
#   'Candidates': 'string'},
#  '1-1431467-4': {'District': 'string',
#   'Incumbent': 'string',
#   'Party': 'string',
#   'First elected': 'real',
#   'Result': 'string',
#   'Candidates': 'string'},
#  '1-14319023-2': {'Year': 'real',
#   'Boys singles': 'string',
#   'Girls singles': 'string',
#   'Boys doubles': 'string',
#   'Girls doubles': 'string',
#   'Mixed doubles': 'string'},
#  '1-14325653-2': {'Year (Ceremony)': 'string',
#   'Video game': 'string',
#   'Publisher(s)': 'string',
#   'Platform(s) [A ]': 'string',
#   'Result': 'string'},
#  '1-14330096-4': {'Total#': 'real',
#   'Series#': 'real',
#   'Title': 'string',
#   'Writer': 'string',
#   'Director': 'string',
#   'Original air date': 'string'},
#  '1-143352-1': {'AGR Power Station': 'string',
#   'Net MWe': 'real',
#   'Construction started': 'real',
#   'Connected to grid': 'real',
#   'Commercial operation': 'real',
#   'Accounting closure date': 'real'},
#  '1-14341967-2': {'Player': 'string',
#   'Touchdowns': 'real',
#   'Extra points': 'real',
#   'Field goals': 'real',
#   'Points': 'real'},
#  '1-14342367-11': {'Player': 'string',
#   'Position': 'string',
#   'Starter': 'string',
#   'Touchdowns': 'real',
#   'Extra points': 'real',
#   'Field goals': 'real',
#   'Points': 'real'},
#  '1-14342367-15': {'Player': 'string',
#   'Touchdowns (5 points)': 'real',
#   'Extra points 1 point': 'real',
#   'Field goals (5 points)': 'real',
#   'Safeties (2 points)': 'real',
#   'Total Points': 'real'},
#  '1-14342367-7': {'Player': 'string',
#   'Position': 'string',
#   'Starter': 'string',
#   'Touchdowns': 'real',
#   'Extra points': 'real',
#   'Field goals': 'real',
#   'Points': 'real'},
#  '1-14342480-5': {'Player': 'string',
#   'Position': 'string',
#   'Starter': 'string',
#   'Touchdowns': 'real',
#   'Extra points': 'real',
#   'Field goals': 'real',
#   'Points': 'real'},
#  '1-14342592-3': {'Player': 'string',
#   'Position': 'string',
#   'Starter': 'string',
#   'Touchdowns': 'real',
#   'Extra points': 'real',
#   'Field goals': 'real',
#   'Points': 'real'},
#  '1-14342592-7': {'Player': 'string',
#   'Position': 'string',
#   'Starter': 'string',
#   'Touchdowns': 'real',
#   'Extra points': 'real',
#   'Field goals': 'real',
#   'Points': 'real'},
#  '1-14345690-1': {'Series': 'string',
#   'Presenters': 'string',
#   'Start date': 'string',
#   'End date': 'string',
#   'Days in camp': 'real',
#   'Camp mates': 'real',
#   'Winner': 'string',
#   'Highest viewers (millions)': 'string',
#   'Lowest viewers (millions)': 'string',
#   'Average viewers (millions)': 'string'},
#  '1-14345690-15': {'Series': 'string',
#   'Main presenter': 'string',
#   'Co-presenter': 'string',
#   'Comedian': 'string',
#   'UK co-presenter': 'string'},
#  '1-14345690-2': {'Celebrity': 'string',
#   'Famous for': 'string',
#   'Entered': 'string',
#   'Exited': 'string',
#   'Finished': 'string'},
#  '1-14345690-3': {'Celebrity': 'string',
#   'Famous for': 'string',
#   'Entered': 'string',
#   'Exited': 'string',
#   'Finished': 'string'},
#  '1-14345690-5': {'Celebrity': 'string',
#   'Famous for': 'string',
#   'Entered': 'string',
#   'Exited': 'string',
#   'Finished': 'string'},
#  '1-14346353-1': {'Series #': 'real',
#   'Title': 'string',
#   'Story by': 'string',
#   'Teleplay by': 'string',
#   'Directed by': 'string',
#   'Original air date': 'string'},
#  '1-1434788-5': {'District': 'string',
#   'Incumbent': 'string',
#   'Party': 'string',
#   'First elected': 'string',
#   'Result': 'string',
#   'Candidates': 'string'},
#  '1-14363116-1': {'Shirt No': 'real',
#   'Nationality': 'string',
#   'Player': 'string',
#   'Birth Date': 'string',
#   'Height': 'real',
#   'Position': 'string'},
#  '1-14368332-1': {'Team': 'string',
#   'Average': 'string',
#   'Points': 'real',
#   'Played': 'real',
#   '1991-92': 'string',
#   '1992-93': 'string',
#   '1993-94': 'real'},
#  '1-14371754-1': {'Team': 'string',
#   'Average': 'string',
#   'Points': 'real',
#   'Played': 'real',
#   '1991-92': 'string',
#   '1992-93': 'string',
#   '1993-94': 'real'},
#  '1-14390413-1': {'Team': 'string',
#   'Average': 'string',
#   'Points': 'real',
#   'Played': 'real',
#   '1989-90': 'string',
#   '1990-91': 'string',
#   '1991-1992': 'real'},
#  ...}

# %%
table["types"]
# Out:
# ['INTEGER',
#  'TEXT',
#  'TEXT',
#  'INTEGER',
#  'TEXT',
#  'TEXT',
#  'TEXT',
#  'TEXT',
#  'TEXT',
#  'TEXT',
#  'TEXT',
#  'TEXT',
#  'TEXT',
#  'INTEGER']

# %%
tables = read_jsonl(schema_file)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-5ea262dd7397> in <module>
#       2 schema_file = data_path / "train_table.jsonl"
#       3 output_file = data_path / "hydra_train.jsonl"
# ----> 4 schema, headers, colTypes, naturalMap = get_schema(read_jsonl(schema_file))
#
# <ipython-input-72-cda3d20ed5d9> in get_schema(tables)
#     103
#     104         trans = {"text": "string", "real": "real", "integer": "integer"}
# --> 105         colTypes[table["id"]] = {col:trans[ty.lower()] for ty, col in zip(table["types"], table["header"])}
#     106         schema[table["id"]] = columns
#     107         naturalMap[table["id"]] = {col: col for col in columns}
#
# <ipython-input-72-cda3d20ed5d9> in <dictcomp>(.0)
#     103
#     104         trans = {"text": "string", "real": "real", "integer": "integer"}
# --> 105         colTypes[table["id"]] = {col:trans[ty.lower()] for ty, col in zip(table["types"], table["header"])}
#     106         schema[table["id"]] = columns
#     107         naturalMap[table["id"]] = {col: col for col in columns}
#
# KeyError: 'timestamp'

# %%
for raw_sample in read_jsonl(src_file):
    break

# %%
table_id = raw_sample["table_id"]
sql = raw_sample["sql"]

cur_schema = schema[table_id]
header = headers[table_id]
cond_col_values = {header[cond[0]]: str(cond[2]) for cond in sql["conds"]}

# %%
column_meta = []
for col in header:
    if col in cond_col_values:
        column_meta.append((col, colTypes[table_id][col], cond_col_values[col]))
    else:
        detected_val = None
        # for cond_col_val in cond_col_values.values():
        #     if cond_col_val.lower() in cur_schema[col]:
        #         detected_val = cond_col_val
        #         break
        column_meta.append((col, colTypes[table_id][col], detected_val))

# %%
cnt = 0

# %%
example = SQLExample(
            cnt,
            raw_sample["question"],
            table_id,
            column_meta,
            sql["agg"],
            int(sql["sel"]),
            [(int(cond[0]), cond[1], str(cond[2])) for cond in sql["conds"]])

# %%
d = example.dump_to_json()

# %%
d = json.loads(d)

# %%
cnt = 0
print("processing {0}...".format(src_file))
with open(output_file, "w", encoding="utf8") as f:
    for raw_sample in utils.read_jsonl(src_file):
        table_id = raw_sample["table_id"]
        sql = raw_sample["sql"]

        cur_schema = schema[table_id]
        header = headers[table_id]
        cond_col_values = {header[cond[0]]: str(cond[2]) for cond in sql["conds"]}
        column_meta = []
        for col in header:
            if col in cond_col_values:
                column_meta.append((col, colTypes[table_id][col], cond_col_values[col]))
            else:
                detected_val = None
                # for cond_col_val in cond_col_values.values():
                #     if cond_col_val.lower() in cur_schema[col]:
                #         detected_val = cond_col_val
                #         break
                column_meta.append((col, colTypes[table_id][col], detected_val))

        example = SQLExample(
            cnt,
            raw_sample["question"],
            table_id,
            column_meta,
            sql["agg"],
            int(sql["sel"]),
            [(int(cond[0]), cond[1], str(cond[2])) for cond in sql["conds"]])

        f.write(example.dump_to_json() + "\n")
        cnt += 1

# %%
s = data[0].strip()

# %%
d = json.loads(s)
keys = ["qid", "question", "table_id", "column_meta", "agg", "select", "conditions", "tokens", "char_to_word", "word_to_char_start", "value_start_end", "valid"]

# %%
d = example.dump_to_json()
# Out:
# {'phase': 1,
#  'table_id': '1-1000181-1',
#  'question': 'Tell me what the notes are for South Australia ',
#  'sql': {'sel': 5, 'conds': [[3, 0, 'SOUTH AUSTRALIA']], 'agg': 0}}

# %%
[d[k] for k in keys]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-9501b5703604> in <module>
# ----> 1 [d[k] for k in keys]
#
# <ipython-input-16-9501b5703604> in <listcomp>(.0)
# ----> 1 [d[k] for k in keys]
#
# KeyError: 'qid'

# %%
class SQLExample(object):
    def __init__(self,
                 qid,
                 question,
                 table_id,
                 column_meta,
                 agg=None,
                 select=None,
                 conditions=None,
                 tokens=None,
                 char_to_word=None,
                 word_to_char_start=None,
                 value_start_end=None,
                 valid=True):
        self.qid = qid
        self.question = question
        self.table_id = table_id
        self.column_meta = column_meta
        self.agg = agg
        self.select = select
        self.conditions = conditions
        self.valid = valid
        if tokens is None:
            self.tokens, self.char_to_word, self.word_to_char_start = basic_tokenize(question)
            self.value_start_end = {}
            if conditions is not None and len(conditions) > 0:
                cur_start = None
                for cond in conditions:
                    value = cond[-1]
                    value_tokens, _, _ = basic_tokenize(value)
                    val_len = len(value_tokens)
                    for i in range(len(self.tokens)):
                        if " ".join(self.tokens[i:i+val_len]).lower() != " ".join(value_tokens).lower():
                            continue
                        s = self.word_to_char_start[i]
                        e = len(question) if i + val_len >= len(self.word_to_char_start) else self.word_to_char_start[i + val_len]
                        recovered_answer_text = question[s:e].strip()
                        if value.lower() == recovered_answer_text.lower():
                            cur_start = i
                            break

                    if cur_start is None:
                        self.valid = False
                        print([value, value_tokens, question, self.tokens])
                        # for c in question:
                        #     print((c, ord(c), unicodedata.category(c)))
                        # raise Exception()
                    else:
                        self.value_start_end[value] = (cur_start, cur_start + val_len)
        else:
            self.tokens, self.char_to_word, self.word_to_char_start, self.value_start_end = tokens, char_to_word, word_to_char_start, value_start_end

    @staticmethod
    def load_from_json(s):
        d = json.loads(s)
        keys = ["qid", "question", "table_id", "column_meta", "agg", "select", "conditions", "tokens", "char_to_word", "word_to_char_start", "value_start_end", "valid"]

        return SQLExample(*[d[k] for k in keys])

    def dump_to_json(self):
        d = {}
        d["qid"] = self.qid
        d["question"] = self.question
        d["table_id"] = self.table_id
        d["column_meta"] = self.column_meta
        d["agg"] = self.agg
        d["select"] = self.select
        d["conditions"] = self.conditions
        d["tokens"] = self.tokens
        d["char_to_word"] = self.char_to_word
        d["word_to_char_start"] = self.word_to_char_start
        d["value_start_end"] = self.value_start_end
        d["valid"] = self.valid

        return json.dumps(d)

    def output_SQ(self, return_str=True):
        agg_ops = ['NA', 'MAX', 'MIN', 'COUNT', 'SUM', 'AVG']
        cond_ops = ['=', '>', '<', 'OP']

        agg_text = agg_ops[self.agg]
        select_text = self.column_meta[self.select][0]
        cond_texts = []
        for wc, op, value_text in self.conditions:
            column_text = self.column_meta[wc][0]
            op_text = cond_ops[op]
            cond_texts.append(column_text + op_text + value_text)

        if return_str:
            sq = agg_text + ", " + select_text + ", " + " AND ".join(cond_texts)
        else:
            sq = (agg_text, select_text, set(cond_texts))
        return sq
